# %% [markdown]
# # Title 1

# %% [markdown]
# ## Parti 1.1 XXX

# %% [markdown]
# ### Importing modules

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv")

# %%
df.groupby("Actor")["Bond Actor Salary"].nlargest(2)
# Out:
# Actor
# Daniel Craig    24    14.5
#                 23     8.1
# George Lazenby  6      0.6
# Pierce Brosnan  21    17.9
#                 20    13.5
# Roger Moore     15     9.1
#                 14     7.8
# Sean Connery    7      5.8
#                 3      4.7
# Timothy Dalton  17     7.9
#                 16     5.2
# Name: Bond Actor Salary, dtype: float64

# %%
cond = df['Actor'].isin(['Sean Connery','Roger Moore','Pierce Brosnan'])
pd.crosstab(df[cond]['Actor'],df[cond]['Director'])
# Out:
# Director        Guy Hamilton  Irvin Kershner  John Glen  Lee Tamahori  \
# Actor
# Pierce Brosnan             0               0          0             1
# Roger Moore                2               0          3             0
# Sean Connery               2               1          0             0
#
# Director        Lewis Gilbert  Martin Campbell  Michael Apted  \
# Actor
# Pierce Brosnan              0                1              1
# Roger Moore                 2                0              0
# Sean Connery                1                0              0
#
# Director        Roger Spottiswoode  Terence Young
# Actor
# Pierce Brosnan                   1              0
# Roger Moore                      0              0
# Sean Connery                     0              3

# %% [markdown]
# ### Part 1.2

# %%
pd.read_csv(
    "https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv",
    dtype={
        'Year':np.float64
    }

)
# Out:
#                                Film    Year           Actor  \
# 0                            Dr. No  1962.0    Sean Connery
# 1             From Russia with Love  1963.0    Sean Connery
# 2                        Goldfinger  1964.0    Sean Connery
# 3                       Thunderball  1965.0    Sean Connery
# 4                     Casino Royale  1967.0     David Niven
# 5               You Only Live Twice  1967.0    Sean Connery
# 6   On Her Majesty's Secret Service  1969.0  George Lazenby
# 7              Diamonds Are Forever  1971.0    Sean Connery
# 8                  Live and Let Die  1973.0     Roger Moore
# 9       The Man with the Golden Gun  1974.0     Roger Moore
# 10             The Spy Who Loved Me  1977.0     Roger Moore
# 11                        Moonraker  1979.0     Roger Moore
# 12               For Your Eyes Only  1981.0     Roger Moore
# 13            Never Say Never Again  1983.0    Sean Connery
# 14                        Octopussy  1983.0     Roger Moore
# ...

# %%
df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
df.max()
# Out:
# Film                 You Only Live Twice
# Year                                2015
# Actor                     Timothy Dalton
# Director                   Terence Young
# Box Office                         943.5
# Budget                             206.3
# Bond Actor Salary                   17.9
# dtype: object

# %%
df.max(axis='index')
# Out:
# Film                 You Only Live Twice
# Year                                2015
# Actor                     Timothy Dalton
# Director                   Terence Young
# Box Office                         943.5
# Budget                             206.3
# Bond Actor Salary                   17.9
# dtype: object

# %%
# Out:
#                                                  Film   Year  \
# 0                                              Dr. No   1962
# 1                         Dr. NoFrom Russia with Love   3925
# 2               Dr. NoFrom Russia with LoveGoldfinger   5889
# 3    Dr. NoFrom Russia with LoveGoldfingerThunderball   7854
# 4   Dr. NoFrom Russia with LoveGoldfingerThunderba...   9821
# 5   Dr. NoFrom Russia with LoveGoldfingerThunderba...  11788
# 6   Dr. NoFrom Russia with LoveGoldfingerThunderba...  13757
# 7   Dr. NoFrom Russia with LoveGoldfingerThunderba...  15728
# 8   Dr. NoFrom Russia with LoveGoldfingerThunderba...  17701
# 9   Dr. NoFrom Russia with LoveGoldfingerThunderba...  19675
# 10  Dr. NoFrom Russia with LoveGoldfingerThunderba...  21652
# 11  Dr. NoFrom Russia with LoveGoldfingerThunderba...  23631
# 12  Dr. NoFrom Russia with LoveGoldfingerThunderba...  25612
# 13  Dr. NoFrom Russia with LoveGoldfingerThunderba...  27595
# ...

# %%
import pandas as pd

# %%
name = ['Freddie','John','Brian','Roger']
surname = ['Mercury','Deacon','May','Taylor'] 
birth = [1946,1951,1947,1949]

# %%
queen = {"name":name, "surname":surname, "birth":birth}

# %%
df = pd.DataFrame(queen)

# %%
df.seek("name")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-21e957464b22> in <module>
# ----> 1 df.seek("name")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'seek'
