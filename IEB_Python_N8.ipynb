# %% [markdown]
# # TABLE OF CONTENTS
# # **IEB MiM&A**
# # Introduction to Python for Data Analysis 🐍📊
# # *Notebook 8: Data Viz with Matplotlib*
# ---
#
# ### TABLE OF CONTENTS
# 1. SCATTER PLOTS
# 2. BAR CHARTS
# 3. TIME SERIES
# 4. EXERCISES
#
# ### 🧑‍🏫 Juan Martin Bellido
# * [linkedin.com/in/jmartinbellido](https://www.linkedin.com/in/jmartinbellido/)
# * juan.martin.bellido.arias@claustro-ieb.es

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import date
import datetime
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# # SCATTER PLOTS
# ---

# %% [markdown]
# Useful links:
# * [Matplotlib documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html)
# * [markers in scatter plots](https://www.tutorialsandyou.com/matplotlib/how-to-change-markers-shape-in-scatter-plot-in-matplotlib-4.html)

# %%
# we create an empty chart
fig, ax = plt.subplots()

# %%
# we import dataframe
df_jamesbond = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv")
df_jamesbond.dtypes
# Out:
# Film                  object
# Year                   int64
# Actor                 object
# Director              object
# Box Office           float64
# Budget               float64
# Bond Actor Salary    float64
# dtype: object

# %%
# Chart 1
fig, ax = plt.subplots(figsize=(12, 8))

ax.scatter(
    df_jamesbond['Budget'], 
    df_jamesbond['Bond Actor Salary'], 
    s=50, 
    facecolor='blue', 
    edgecolor='black'
)

ax.set(xlabel="Budget",
       ylabel="Bond Actor Salary",
       title="Chart Title")

plt.savefig('my_chart.png', dpi=100) # we use .savefig() to export chart

# %%
# Chart 2
fig, ax = plt.subplots(figsize=(12, 8))
ax.scatter(
    df_jamesbond[df_jamesbond['Actor']=='Sean Connery']['Budget'], 
    df_jamesbond[df_jamesbond['Actor']=='Sean Connery']['Bond Actor Salary'],
    label='Sean Connery',
    s=50,
    marker='o',   # 
    facecolor='blue', 
    edgecolor='black'
)

ax.scatter(
    df_jamesbond[df_jamesbond['Actor']=='Pierce Brosnan']['Budget'], 
    df_jamesbond[df_jamesbond['Actor']=='Pierce Brosnan']['Bond Actor Salary'],
    label='Pierce Brosnan',
    s=50,
    marker='s',
    facecolor='orange', 
    edgecolor='black'
)

ax.scatter(
    df_jamesbond[df_jamesbond['Actor']=='Daniel Craig']['Budget'], 
    df_jamesbond[df_jamesbond['Actor']=='Daniel Craig']['Bond Actor Salary'],
    label='Daniel Craig',
    s=50,
    marker='^',
    facecolor='green', 
    edgecolor='black'
)

ax.set(xlabel="Budget",
       ylabel="Bond Actor Salary",
       title="Budget vs. Salary"
)

ax.legend()

# %%
# Chart 3
# we create a plot with 2 charts (2x1)
fig, ax = plt.subplots(2,1,sharex=True,figsize=(12, 8))

# Chart 1
ax[0].scatter(
    df_jamesbond[df_jamesbond['Actor']=='Sean Connery']['Budget'], 
    df_jamesbond[df_jamesbond['Actor']=='Sean Connery']['Bond Actor Salary'],
    s=50,
    marker='o',
    facecolor='blue', 
    edgecolor='black'
)

ax[0].set(
    xlabel="Budget",
    ylabel="Bond Actor Salary",
    title="James Bond Movies - Budget vs. Bond Actor Salary\nSean Connery"
)

# Chart 2
ax[1].scatter(
    df_jamesbond[df_jamesbond['Actor']=='Pierce Brosnan']['Budget'], 
    df_jamesbond[df_jamesbond['Actor']=='Pierce Brosnan']['Bond Actor Salary'],
    s=50,
    marker='s',
    facecolor='orange', 
    edgecolor='black'
)

ax[1].set(
    xlabel="Budget",
    ylabel="Bond Actor Salary",
    title="Pierce Brosnan"
)
# Out:
# [Text(0, 0.5, 'Bond Actor Salary'),
#  Text(0.5, 0, 'Budget'),
#  Text(0.5, 1.0, 'Pierce Brosnan')]

# %%
# Chart 4
# we create a plot with 4 charts (2x2)
fig, ax = plt.subplots(2,2,sharex=True, sharey=True,figsize=(12, 8))

# Chart A
ax[0,0].scatter(
    df_jamesbond[df_jamesbond['Actor']=='Sean Connery']['Budget'], 
    df_jamesbond[df_jamesbond['Actor']=='Sean Connery']['Bond Actor Salary'],
    s=50,
    marker='o',
    facecolor='blue', 
    edgecolor='black'
)

ax[0,0].set(
    xlabel="Budget",
    ylabel="Bond Actor Salary",
    title="James Bond Movies - Budget vs. Bond Actor Salary\nSean Connery"
)

# Chart B
ax[0,1].scatter(
    df_jamesbond[df_jamesbond['Actor']=='Pierce Brosnan']['Budget'], 
    df_jamesbond[df_jamesbond['Actor']=='Pierce Brosnan']['Bond Actor Salary'],
    s=50,
    marker='s',
    facecolor='orange', 
    edgecolor='black'
)

ax[0,1].set(
    xlabel="Budget",
    ylabel="Bond Actor Salary",
    title="Pierce Brosnan"
)

# Chart C
ax[1,0].scatter(
    df_jamesbond[df_jamesbond['Actor']=='Daniel Craig']['Budget'], 
    df_jamesbond[df_jamesbond['Actor']=='Daniel Craig']['Bond Actor Salary'],
    s=50,
    marker='^',
    facecolor='green', 
    edgecolor='black'
)

ax[0,1].set(
    xlabel="Budget",
    ylabel="Bond Actor Salary",
    title="Daniel Craig"
)

# Chart D

ax[1,1].scatter(
    df_jamesbond[df_jamesbond['Actor']=='Roger Moore']['Budget'], 
    df_jamesbond[df_jamesbond['Actor']=='Roger Moore']['Bond Actor Salary'],
    s=50,
    marker='v',
    facecolor='red', 
    edgecolor='black'
)

ax[1,1].set(xlabel="Budget",
       ylabel="Bond Actor Salary",
       title="Roger Moore")
# Out:
# [Text(0, 0.5, 'Bond Actor Salary'),
#  Text(0.5, 0, 'Budget'),
#  Text(0.5, 1.0, 'Roger Moore')]

# %% [markdown]
# # BAR CHARTS
# ---
# Useful links:
# * [Matplotlib documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html)

# %%
# we import dataframe
df_jamesbond = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv")
df_jamesbond.dtypes
# Out:
# Film                  object
# Year                   int64
# Actor                 object
# Director              object
# Box Office           float64
# Budget               float64
# Bond Actor Salary    float64
# dtype: object

# %%
# Chart 1
df = df_jamesbond['Actor'].value_counts()
df = df.reset_index().rename({'index':'Actor','Actor':'Count_Movies'},axis=1)

fig, ax = plt.subplots(
    figsize=(12,8)
)

ax.bar(
    df['Actor'],
    df['Count_Movies'],
    width=0.75, 
    edgecolor="white", 
    linewidth=1,
    facecolor='orange'
)
# Out:
# <BarContainer object of 7 artists>

# %%
# Chart 2
df = df_jamesbond['Actor'].value_counts()
df = df.reset_index()\
    .rename({'index':'Actor','Actor':'Count_Movies'},axis=1)\
    .sort_values('Count_Movies')

fig, ax = plt.subplots(
    figsize=(12,8)
)

ax.barh(
    df['Actor'],
    df['Count_Movies'],
    height=0.75, 
    edgecolor="white", 
    linewidth=1,
    facecolor='orange'
)
# Out:
# <BarContainer object of 7 artists>

# %%
# Chart 3
df = df_jamesbond['Actor'].value_counts()
df = df.reset_index().rename({'index':'Actor','Actor':'Count_Movies'},axis=1)

fig, ax = plt.subplots(
    figsize=(12,8)
)

ax.bar(
    df['Actor'],
    df['Count_Movies'],
    width=0.75, 
    edgecolor="white", 
    linewidth=1,
    facecolor='grey'
)

ax.bar(
    df['Actor'][0],
    df['Count_Movies'][0],
    width=0.75, 
    edgecolor="white", 
    linewidth=1,
    facecolor='orange'
)

ax.annotate(
    'Highest number of movies', 
    xy=(0, 6), 
    xytext=(3, 7),
    arrowprops=dict(facecolor='black', shrink=0.05),
    fontsize=15
)

ax.set(
    xlabel="James Bond Actor",
    ylabel="Total Number of Movies",
    title="Actors by Total Movies"
)
# Out:
# [Text(0, 0.5, 'Total Number of Movies'),
#  Text(0.5, 0, 'James Bond Actor'),
#  Text(0.5, 1.0, 'Actors by Total Movies')]

# %% [markdown]
# # TIME SERIES
# ---
# Useful links:
# * [Matplotlib documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
# we import df
df_amzn = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/amzn_stocks.csv")
df_amzn.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
# we use pd.to_datetime() to convert column into formal date format
df_amzn['Date'] = pd.to_datetime(df_amzn['Date'])
df_amzn.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume             int64
# dtype: object

# %%
df_amzn['day'] = df_amzn['Date'].dt.day

# %%
# Chart 1
df = df_amzn[df_amzn.Date > '2017-07-01']

fig, ax = plt.subplots()

ax.plot(
    df['day'],
    df['Open'],
    color = 'black',
    linewidth=1
)

# Set title and labels for axes
ax.set(xlabel="Day",
       ylabel="Stock Rates ($)",
       title="AMZN Stock Rates\nJuly 2017"
)
# Out:
# [Text(0, 0.5, 'Stock Rates ($)'),
#  Text(0.5, 0, 'Day'),
#  Text(0.5, 1.0, 'AMZN Stock Rates\nJuly 2017')]

# %%
# Chart 2
df = df_amzn[df_amzn.Date > '2017-07-01']

fig, ax = plt.subplots()

ax.plot(
    df['Date'],
    df['Open'],
    color = 'black',
    linewidth=1
)

# Set title and labels for axes
ax.set(xlabel="Day",
       ylabel="Stock Rates ($)",
       title="Title Line 1",)

# Define the date format
date_form = mdates.DateFormatter("%m-%d")
ax.xaxis.set_major_formatter(date_form)

# %%
# Chart 3
df = df_amzn

fig, ax = plt.subplots(figsize=(10,8))
ax.plot(
    df['Date'],
    df['Open'],
    color = 'black',
    linewidth=1.5
)

ax.set(
    title="AMZN 2017 Stock Rates",
    xlabel="Date",
    ylabel="Stock Rates ($)",
    xlim=(datetime.date(2017, 5, 1), datetime.date(2017, 6, 27)),
    ylim = (900,1050),
    yticks=np.arange(900, 1050, step=10),
)

# Define labels in date format
date_form = mdates.DateFormatter("%m-%d")
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
#ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=1))

# %%
# Chart 4
df = df_amzn

fig, ax = plt.subplots(figsize=(10,8))

ax.set(
    title="AMZN 2017 Stock Rates",
    xlabel="Date",
    ylabel="Stock Rates ($)",
    xlim=(datetime.date(2017, 5, 1), datetime.date(2017, 6, 27)),
    ylim = (900,1050),
    yticks=np.arange(900, 1050, step=10),
)

ax.plot(
    df['Date'],
    df['Open'],
    color = 'black',
    linewidth=1.5
)

ax.plot(
    df['Date'],
    df['High'],
    color = 'green',
    linewidth=1.5,
    linestyle='--'
)

ax.plot(
    df['Date'],
    df['Low'],
    color = 'red',
    linewidth=1.5,
    linestyle='--'
)

# Define labels in date format
date_form = mdates.DateFormatter("%m-%d")
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
#ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=1))

# %% [markdown]
# # EXERCISES

# %% [markdown]
# ##### EX 1: Scatter plot
# ---
# Build a scatter plot using Matplotlib to visualize movie IMDB Score vs. Budget.
# * Include only movies that are directed by top 3 directors with highest number of movies
# * Use different colors and markers to display movies by each direactor
#
# > https://data-wizards.s3.amazonaws.com/datasets/dataset_na_who.csv
#
# ![title](https://data-wizards.s3.amazonaws.com/img/matplotlib/EX1.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import date
import datetime
import numpy as np

# %%
# %matplotlib inline

# %%
df_movies = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/movies.csv")
df_movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
freq_directors = df_movies['director_name'].value_counts()
select_directors = freq_directors.reset_index()['index']
df = df_movies[df_movies['director_name'].isin(select_directors)][['director_name','imdb_score','budget']]
df['budget'] = df['budget']/1000000

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# director 1
ax.scatter(
    x = df[df['director_name']==select_directors[0]]['budget'], 
    y = df[df['director_name']==select_directors[0]]['imdb_score'], 
    s=50, 
    facecolor='blue', 
    edgecolor='blue',
    marker='o',
    label=select_directors[0]
)

# director 2
ax.scatter(
    x = df[df['director_name']==select_directors[1]]['budget'], 
    y = df[df['director_name']==select_directors[1]]['imdb_score'], 
    s=50, 
    facecolor='red', 
    edgecolor='red',
    marker='^',
    label=select_directors[1]
)

# director 3
ax.scatter(
    x = df[df['director_name']==select_directors[2]]['budget'], 
    y = df[df['director_name']==select_directors[2]]['imdb_score'], 
    s=50, 
    facecolor='green', 
    edgecolor='green',
    marker='v',
    label=select_directors[2]
)

ax.set(xlabel="Budget (USD Million)",
       ylabel="IMDB Score",
       title="Budget vs. IMDB Score\nTop 3 Directores with Highest Number of Movies")

ax.legend()

# %% [markdown]
# ##### EX 2: Scatter plot
# ---
# Repeat exercise 1, this time separate movies by directors on independent charts. Include 4th director with highest number of movies.
#
# ![title](https://data-wizards.s3.amazonaws.com/img/matplotlib/EX2.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import date
import datetime
import numpy as np

# %%
# %matplotlib inline

# %%
df_movies = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/movies.csv")
df_movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
freq_directors = df_movies['director_name'].value_counts()
select_directors = freq_directors.reset_index()['index']
df = df_movies[df_movies['director_name'].isin(select_directors)][['director_name','imdb_score','budget']]
df['budget'] = df['budget']/1000000

# %%
fig, ax = plt.subplots(2,2,figsize=(12, 8),sharex=True, sharey=True)

# director 1
ax[0,0].set_title(select_directors[0])
ax[0,0].scatter(
    x = df[df['director_name']==select_directors[0]]['budget'], 
    y = df[df['director_name']==select_directors[0]]['imdb_score'], 
    s=50, 
    facecolor='blue', 
    edgecolor='blue',
    marker='o'
)

# director 2
ax[1,0].set_title(select_directors[1])
ax[1,0].scatter(
    x = df[df['director_name']==select_directors[1]]['budget'], 
    y = df[df['director_name']==select_directors[1]]['imdb_score'], 
    s=50, 
    facecolor='red', 
    edgecolor='red',
    marker='^'
)

# director 3
ax[0,1].set_title(select_directors[2])
ax[0,1].scatter(
    x = df[df['director_name']==select_directors[2]]['budget'], 
    y = df[df['director_name']==select_directors[2]]['imdb_score'], 
    s=50, 
    facecolor='green', 
    edgecolor='green',
    marker='v'
)

# director 4
ax[1,1].set_title(select_directors[3])
ax[1,1].scatter(
    x = df[df['director_name']==select_directors[3]]['budget'], 
    y = df[df['director_name']==select_directors[3]]['imdb_score'], 
    s=50, 
    facecolor='orange', 
    edgecolor='orange',
    marker='s'
)

ax[1,0].set_xlabel('Budget (USD Million)')
ax[1,1].set_xlabel('Budget (USD Million)')
ax[0,0].set_ylabel('IMDB Score')
ax[1,0].set_ylabel('IMDB Score')
# Out:
# Text(0, 0.5, 'IMDB Score')

# %% [markdown]
# ##### EX 3: Bar Charts
# ---
# Build a bar chart using Matplotlib to visualize average GDP per capita by continent. Highlight Europe on a different color.
#
# > https://data-wizards.s3.amazonaws.com/datasets/dataset_na_who.csv
#
# ![title](https://data-wizards.s3.amazonaws.com/img/matplotlib/EX5.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import date
import datetime
import numpy as np

# %%
# %matplotlib inline

# %%
df_who = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/dataset_na_who.csv")
df_who.dtypes
# Out:
# Country                                                    object
# CountryID                                                   int64
# ContinentID                                                 int64
# Adolescent fertility rate (%)                             float64
# Adult literacy rate (%)                                   float64
# Gross national income per capita (PPP international $)    float64
# Net primary school enrolment ratio female (%)             float64
# Net primary school enrolment ratio male (%)               float64
# Population (in thousands) total                           float64
# Population annual growth rate (%)                         float64
# Population in urban areas (%)                             float64
# Population living below the poverty line                  float64
# Continent                                                  object
# dtype: object

# %%
df = df_who.groupby("Continent")\
    .agg({'Gross national income per capita (PPP international $)':'sum'})\
    .rename({'Gross national income per capita (PPP international $)':'GDP_per_capita'},axis=1)\
    .sort_values('GDP_per_capita',ascending=False)

df = df.reset_index()

fig, ax = plt.subplots(figsize = (12,8))

ax.set_title("GDP Per Capita by Continent\nWorld Health Organization")
ax.bar(
    df['Continent'],
    df['GDP_per_capita'],
    width=0.75, 
    edgecolor="white", 
    linewidth=1,
    facecolor='grey'
)

ax.bar(
    df[df.Continent =='Europe']['Continent'],
    df[df.Continent =='Europe']['GDP_per_capita'],
    width=0.75, 
    edgecolor="white", 
    linewidth=1,
    facecolor='orange'
)

ax.set_xlabel("Continent")
ax.set_ylabel("GDP Per Capita")
# Out:
# Text(0, 0.5, 'GDP Per Capita')

# %% [markdown]
# ##### EX 4: Bar Charts
# ---
# Repeat exercise 3, this time include an extra bar chart (see image) to visualize GDP per capita by country in EU.
#
# > https://data-wizards.s3.amazonaws.com/datasets/dataset_na_who.csv
#
# ![title](https://data-wizards.s3.amazonaws.com/img/matplotlib/EX6.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import date
import datetime
import numpy as np

# %%
# %matplotlib inline

# %%
df_who = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/dataset_na_who.csv")
df_who.dtypes
# Out:
# Country                                                    object
# CountryID                                                   int64
# ContinentID                                                 int64
# Adolescent fertility rate (%)                             float64
# Adult literacy rate (%)                                   float64
# Gross national income per capita (PPP international $)    float64
# Net primary school enrolment ratio female (%)             float64
# Net primary school enrolment ratio male (%)               float64
# Population (in thousands) total                           float64
# Population annual growth rate (%)                         float64
# Population in urban areas (%)                             float64
# Population living below the poverty line                  float64
# Continent                                                  object
# dtype: object

# %%
fig, ax = plt.subplots(2,1,figsize = (12,22))

# chart 1

df = df_who.groupby("Continent")\
    .agg({'Gross national income per capita (PPP international $)':'sum'})\
    .rename({'Gross national income per capita (PPP international $)':'GDP_per_capita'},axis=1)\
    .sort_values('GDP_per_capita',ascending=False)

df = df.reset_index()

ax[0].set_title("World Health Organization\nGDP per capita by Continent")
ax[0].bar(
    df['Continent'],
    df['GDP_per_capita'],
    width=0.75, 
    edgecolor="white", 
    linewidth=1,
    facecolor='grey'
)

ax[0].bar(
    df[df.Continent =='Europe']['Continent'],
    df[df.Continent =='Europe']['GDP_per_capita'],
    width=0.75, 
    edgecolor="white", 
    linewidth=1,
    facecolor='orange'
)

ax[0].set_xlabel("Continent")
ax[0].set_ylabel("GDP Per Capita")

# chart 2

df = df_who[df_who.Continent == 'Europe']\
    .rename({'Gross national income per capita (PPP international $)':'GDP_per_capita'},axis=1)\
    .sort_values('GDP_per_capita')

cond = df['GDP_per_capita'].isna()
df = df[-cond]

ax[1].set_title("GDP Per Capita by Country in EU")
ax[1].barh(
    df['Country'],
    df['GDP_per_capita'],
    edgecolor="white", 
    linewidth=1,
    facecolor='grey'
)
# Out:
# <BarContainer object of 48 artists>

# %% [markdown]
# ##### EX 5: Time Series
# ---
# The dataset below contains historical data for an ecommerce. Build a time series chart to visualize weekly orders and visits during H1 2017 (see image below).
#
# > https://data-wizards.s3.amazonaws.com/datasets/ga_merchant_store.csv
#
# ![title](https://data-wizards.s3.amazonaws.com/img/matplotlib/EX3.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import date
import datetime
import numpy as np

# %%
# %matplotlib inline

# %%
df_google_analytics = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/ga_merchant_store.csv")
df_google_analytics.dtypes
# Out:
# date                object
# channelGrouping     object
# campaign            object
# source              object
# medium              object
# timeOnSite         float64
# bounces            float64
# visits               int64
# transactions       float64
# newVisits          float64
# dtype: object

# %%
df_google_analytics['date'] = pd.to_datetime(df_google_analytics['date'])
df_google_analytics.dtypes
# Out:
# date               datetime64[ns]
# channelGrouping            object
# campaign                   object
# source                     object
# medium                     object
# timeOnSite                float64
# bounces                   float64
# visits                      int64
# transactions              float64
# newVisits                 float64
# dtype: object

# %%
df_google_analytics['week'] = df_google_analytics['date'].dt.isocalendar().week
df_google_analytics['month'] = df_google_analytics['date'].dt.month
df_google_analytics['year'] = df_google_analytics['date'].dt.year
df_google_analytics.head()
# Out:
#         date channelGrouping   campaign  ... week month  year
# 0 2016-08-01        Referral  (not set)  ...   31     8  2016
# 1 2016-08-01        Referral  (not set)  ...   31     8  2016
# 2 2016-08-01  Organic Search  (not set)  ...   31     8  2016
# 3 2016-08-01        Referral  (not set)  ...   31     8  2016
# 4 2016-08-01        Referral  (not set)  ...   31     8  2016
#
# [5 rows x 13 columns]

# %%
cond_1 = df_google_analytics.year == 2017
cond_2 = df_google_analytics.month < 7
cond_3 = df_google_analytics.week==52

df = df_google_analytics[cond_1 & cond_2 & -cond_3].groupby('week').agg({'transactions':'sum','visits':'sum'})
df = df.reset_index()
df
# Out:
#     week  transactions  visits
# 0      1         167.0   14068
# 1      2         147.0   14033
# 2      3         151.0   14136
# 3      4         162.0   16472
# 4      5         187.0   14691
# 5      6         155.0   15712
# 6      7         245.0   16540
# 7      8         162.0   15171
# 8      9         267.0   15098
# 9     10         182.0   15344
# 10    11         207.0   15285
# 11    12         200.0   16277
# 12    13         222.0   16657
# 13    14         226.0   16519
# 14    15         216.0   14515
# 15    16         237.0   14811
# 16    17         254.0   17250
# 17    18         330.0   15289
# 18    19         273.0   12848
# 19    20         259.0   17013
# 20    21         185.0   13985
# 21    22         215.0   14185
# 22    23         206.0   14470
# 23    24         273.0   14147
# 24    25         208.0   14102
# 25    26         182.0   12910

# %%
fig, ax = plt.subplots(2,1,figsize=(10,8))

ax[0].set_title("H1 2017\nWeekly Transactions")
ax[0].set_ylabel("Orders")
ax[0].plot(
    df['week'],
    df['transactions'],
    color = 'red',
    linewidth=1.5
)

ax[1].set_title("Weekly Visits")
ax[1].set_ylabel("Visits (K)")
ax[1].plot(
    df['week'],
    df['visits']/1000,
    color = 'blue',
    linewidth=1.5
)

ax[1].set_xlabel("Week Number")

ax[0].set_xticks(np.arange(df['week'].min(), df['week'].max(), step=1))
ax[1].set_xticks(np.arange(df['week'].min(), df['week'].max(), step=1))

# %% [markdown]
# ##### EX 6: Time Series
# ---
# Repeat exercise 5, this time include bar charts to show top channels and sources in terms of total visits during Hi 2017.
#
# > https://data-wizards.s3.amazonaws.com/datasets/ga_merchant_store.csv
#
# ![title](https://data-wizards.s3.amazonaws.com/img/matplotlib/EX4.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import date
import datetime
import numpy as np

# %%
# %matplotlib inline

# %%
df_google_analytics = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/ga_merchant_store.csv")
df_google_analytics.dtypes
# Out:
# date                object
# channelGrouping     object
# campaign            object
# source              object
# medium              object
# timeOnSite         float64
# bounces            float64
# visits               int64
# transactions       float64
# newVisits          float64
# dtype: object

# %%
df_google_analytics['date'] = pd.to_datetime(df_google_analytics['date'])
df_google_analytics.dtypes
# Out:
# date               datetime64[ns]
# channelGrouping            object
# campaign                   object
# source                     object
# medium                     object
# timeOnSite                float64
# bounces                   float64
# visits                      int64
# transactions              float64
# newVisits                 float64
# dtype: object

# %%
df_google_analytics['week'] = df_google_analytics['date'].dt.isocalendar().week
df_google_analytics['month'] = df_google_analytics['date'].dt.month
df_google_analytics['year'] = df_google_analytics['date'].dt.year
df_google_analytics.head()
# Out:
#         date channelGrouping   campaign  ... week month  year
# 0 2016-08-01        Referral  (not set)  ...   31     8  2016
# 1 2016-08-01        Referral  (not set)  ...   31     8  2016
# 2 2016-08-01  Organic Search  (not set)  ...   31     8  2016
# 3 2016-08-01        Referral  (not set)  ...   31     8  2016
# 4 2016-08-01        Referral  (not set)  ...   31     8  2016
#
# [5 rows x 13 columns]

# %%
cond_1 = df_google_analytics.year == 2017
cond_2 = df_google_analytics.month < 7
cond_3 = df_google_analytics.week==52

fig, ax = plt.subplots(2,2, figsize = (15,10))

fig.tight_layout(pad=9)

# charts 1 & 2

df = df_google_analytics[cond_1 & cond_2 & -cond_3].groupby('week').agg({'transactions':'sum','visits':'sum'})
df = df.reset_index()

ax[0,0].set_title("H1 2017\nWeekly Transactions")
ax[0,0].set_ylabel("Orders")
ax[0,0].plot(
    df['week'],
    df['transactions'],
    color = 'red',
    linewidth=1.5
)

ax[1,0].set_title("H1 2017\nWeekly Visits")
ax[1,0].set_ylabel("Visits (K)")
ax[1,0].plot(
    df['week'],
    df['visits']/1000,
    color = 'blue',
    linewidth=1.5
)

ax[1,0].set_xlabel("Week Number")

ax[0,0].set_xticks(np.arange(df['week'].min(), df['week'].max(), step=2))
ax[1,0].set_xticks(np.arange(df['week'].min(), df['week'].max(), step=2))

# charts 3

df = df_google_analytics[cond_1 & cond_2 & -cond_3]\
    .groupby('channelGrouping')\
    .agg({'visits':'sum'})\
    .sort_values('visits')
df = df.reset_index()

ax[0,1].set_title("H1 2017\nTotal Visits by Channel")
ax[0,1].barh(
    df['channelGrouping'],
    df['visits']/1000,
    #width=0.75, 
    edgecolor="white", 
    linewidth=1,
    facecolor='grey'
)
ax[0,1].set_xlabel("Visits (K)")

# chart 4

df = df_google_analytics[cond_1 & cond_2 & -cond_3]\
    .groupby('source')\
    .agg({'visits':'sum'})\
    .sort_values('visits',ascending=False)\
    .head(7)\
    .sort_values('visits')
df = df.reset_index()

ax[1,1].set_title("H1 2017\nTotal Visits by Source")
ax[1,1].barh(
    df['source'],
    df['visits']/1000,
    #width=0.75, 
    edgecolor="white", 
    linewidth=1,
    facecolor='grey'
)
ax[1,1].set_xlabel("Visits (K)")
# Out:
# Text(0.5, 69.00000000000009, 'Visits (K)')
